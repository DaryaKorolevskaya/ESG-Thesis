# %%
import copy
import re
from collections import defaultdict
import pickle

import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import numpy as np

# %%
topics = pd.read_csv("../topic_words.csv.zip")
topics.head(10)
# Out:
#   meta             topic  weight  type              word
# 0  env  Экология в целом       5     0       воздействие
# 1  env  Экология в целом       5     0  окружающая среда
# 2  env  Экология в целом       5     0           природа
# 3  env  Экология в целом       5     0   природоохранный
# 4  env  Экология в целом       5     0     экологический
# 5  env  Экология в целом       5     0       экологичный
# 6  env  Экология в целом       1     0           влияние
# 7  env  Экология в целом       1     0          документ
# 8  env  Экология в целом       1     0      документация
# 9  env  Экология в целом       1     0            защита

# %%
topics["topic"].value_counts()
pass

# %%
re_dict = {}
re_advanced_dict = {}
sheets_dict = {}
sheets_advanced_dict = {}
base_dict = {}
advanced_dict = {}
importance_dict = {}

for idx, row in topics.iterrows():
    if not sheets_dict.get(row["topic"], False):
        sheets_dict[row["topic"]] = {}
        sheets_advanced_dict[row["topic"]] = {}
        base_dict[row["topic"]] = {}
        advanced_dict[row["topic"]] = {}
    if row["word"].find(",") != -1:
        continue
    sheets_dict[row["topic"]][row["word"]] = row["weight"]  # row["type"]
    if row["type"] == 1:
        sheets_advanced_dict[row["topic"]][row["word"]] = row["weight"]
        advanced_dict[row["topic"]][row["word"]] = 0
    base_dict[row["topic"]][row["word"]] = 0
    importance_dict[row["topic"]] = 0

# %%
for key, val in sheets_dict.items():
    re_dict[key] = re.compile("((?<!\w)" + "(?!\w)|(?<!\w)".join(val.keys()) + "(?!\w))")

# %%
for key, val in sheets_advanced_dict.items():
    re_advanced_dict[key] = re.compile("((?<!\w)" + "(?!\w)|(?<!\w)".join(val.keys()) + "(?!\w))")

# %% [markdown]
# # Feature matrix

# %%
regex_expert = re.compile("(" + "(?!\w)|".join(topics["word"].unique()) + "(?!\w))")

# %%
label2idx = {topic: i for i, topic in enumerate(sorted(topics["topic"].unique()))}
idx2label = {i: topic for i, topic in enumerate(sorted(topics["topic"].unique()))}
idx2word = {i: word for i, word in enumerate(topics["word"].tolist())}
word2idx = defaultdict(list)

for i, word in enumerate(topics["word"].tolist()):
    word2idx[word].append(i)

# %%
topics_vectors = np.zeros((topics["topic"].nunique(), topics.shape[0]), dtype=int)

for topic, topic_words in topics.groupby("topic")["word"].agg(list).items():
    for word in topic_words:
        for idx in word2idx[word]:
            topics_vectors[label2idx[topic], idx] = 1

# %%
df = pd.read_csv("etalon/etalon_paragraphs.csv", on_bad_lines='skip')
df
# Out:
#       Unnamed: 0                                      original_text  \
# 0              0  в соответствии с внутренними документами компа...
# 1              1  в 2022 году компания продолжила совершенствова...
# 2              2  на прошедших в 2022 году собраниях успешно при...
# 3              3  при организации системы корпоративного управле...
# 4              4  система корпоративного управления выстроена с ...
# ...          ...                                                ...
# 1420        1420  рост регулируемых тарифов сетевых организаций ...
# 1421        1421  втб стремится обеспечить доступное жилищное кр...
# 1422        1422  приобрести автомобиль в рамках госпрограммы мо...
# 1423        1423  втб выдает кредиты на льготных условиях в рамк...
# 1424        1424  в октябре 2022 года втб начал принимать заявки...
#
#                                            cleaned_text  \
# 0     соответствие внутренний документ компания стру...
# 1     2022 год компания продолжить совершенствовать ...
# 2     прошедшее 2022 год собрание успешно применятьс...
# 3     организация система корпоративный управление к...
# 4     корпоративный управление выстроить учёт рекоме...
# ...                                                 ...
# 1420  рост регулировать тариф сетевой организация ка...
# 1421  стремиться обеспечить доступный жилищный креди...
# 1422  приобрести автомобиль рамка госпрограмма мочь ...
# 1423  выдавать кредит льготный условие рамка государ...
# 1424  октябрь 2022 год начать принимать заявка покуп...
#
#                         true_expert
# 0          Корпоративное управление
# 1          Корпоративное управление
# 2          Корпоративное управление
# 3          Корпоративное управление
# 4          Корпоративное управление
# ...                             ...
# 1420  Потребители. Ценовая политика
# 1421  Потребители. Ценовая политика
# 1422  Потребители. Ценовая политика
# 1423  Потребители. Ценовая политика
# 1424  Потребители. Ценовая политика
#
# [1425 rows x 4 columns]

# %%
vector = []
labels = []
found_words = []
true_expert_found_words = []
texts = []

for i, (text, expert_topic, original_text) in tqdm(
    enumerate(zip(df["cleaned_text"], df["true_expert"], df["original_text"])), total=df["cleaned_text"].shape[0]
):
    tmp = np.zeros(topics_vectors.shape[1])
    if pd.isna(text):
        continue

    if not re_dict.get(expert_topic, False):
        continue

    if len(re_dict[expert_topic].findall(text)) < 5:
        continue

    texts.append({"text": text, "topic": expert_topic, "original_text": original_text})

    text_words = {}
    for key, regex in re_dict.items():
        words = regex.findall(text)
        text_words[key] = words
        if key == expert_topic:
            true_expert_found_words.append((key, words))
        for word in words:
            tmp[word2idx[word]] = 1
    vector.append(tmp)
    labels.append(expert_topic)
    found_words.append(text_words)
# Out:
# 100%|██████████████████████████████████████| 1425/1425 [00:11<00:00, 119.30it/s]

# %%
pd.DataFrame(texts).to_csv("etalon/et_used_texts_expert.csv")

# %%
vector = np.vstack(vector)

# %%
w = pd.DataFrame(found_words)
w.head(5)
# Out:
#                                     Экология в целом  \
# 0  [документ, управление, управление, управление,...
# 1                                                 []
# 2  [система, управление, управление, управление, ...
# 3  [управление, управление, управление, управлени...
# 4  [система, управление, система, управление, упр...
#
#                                               Климат  \
# 0                                                 []
# 1                                         [(учёт, )]
# 2                     [(реализация, ), (рыночный, )]
# 3                                         [(учёт, )]
# 4  [(стратегия, ), (стратегия, ), (реализация, ),...
#
#                                              Энергия  \
# 0  [общий, высокий, решение, общий, общий, работа...
# 1                                     [общий, общий]
# 2                                 [система, высокий]
# 3                                            [общий]
# 4  [система, система, решение, работа, система, в...
#
#                                               Воздух               Вода  \
# 0               [управление, управление, управление]        [структура]
# 1                                            [смочь]             [учёт]
# 2  [управление, управление, управление, управлени...        [поставщик]
# 3  [управление, управление, управление, управлени...  [учёт, структура]
# 4  [управление, управление, управление, управлени...                 []
#
#             Отходы и циклическая экономика  Биоразнообразие  \
# 0                                 [защита]               []
# 1  [электронный, электронный, электронный]               []
# 2                   [повышение, стоимость]  [международный]
# 3                   [устойчивый, развитие]               []
# 4  [повышать, защита, развитие, повышение]   [существенный]
#
#                                 Рекультивация земель  \
# 0                                         [контроль]
# 1                                                 []
# 2                            [российский, закрепить]
# 3                                       [российский]
# 4  [российский, законодательство, контроль, контр...
#
#        Экологичность продукта !Персонал в целом  ...  \
# 0               [эффективный]  [работа, работа]  ...
# 1                          []                []  ...
# 2               [эффективный]       [отношение]  ...
# 3                          []                []  ...
# 4  [эффективный, эффективный]          [работа]  ...
#
#                            Отчетность и прозрачность  \
# 0  [внутренний, директор, директор, директор, дир...
# 1                                                 []
# 2                                          [принцип]
# 3                     [директор, директор, директор]
# 4  [уверенность, принцип, контроль, контроль, рис...
#
#                              Отношения с инвесторами !Инновации  \
# 0  [собрание, акционер, деятельность, деятельност...         []
# 1  [собрание, акционер, акционер, акционер, акцио...         []
# 2  [деятельность, прозрачный, акционер, равный, о...         []
# 3   [листинг, московский, биржа, собрание, акционер]         []
# 4                               [акционер, общество]         []
#
#   !Кибербезопасность                                     Права человека  \
# 0                 []   [оперативный, обеспечивать, обеспечивать, право]
# 1                 []                                            [право]
# 2                 []  [кодекс, кодекс, кодекс, закрепить, механизм, ...
# 3                 []                                 [кодекс, развитие]
# 4             [риск]  [обеспечивать, право, развитие, риск, предотвр...
#
#                                            Лидерство  \
# 0  [собрание, совет, директор, руководство, компе...
# 1            [собрание, годовой, собрание, собрание]
# 2       [кодекс, кодекс, кодекс, принцип, сотрудник]
# 3  [кодекс, собрание, совет, директор, генеральны...
# 4  [принятие, принцип, принятие, этический принци...
#
#                                                Риски  \
# 0        [основный, предварительный, важный, защита]
# 1                                                 []
# 2                                          [сторона]
# 3                                                 []
# 4  [уверенность, сторона, защита, управление риск...
#
#       Этика и антикоррупция  \
# 0                 [комитет]
# 1                        []
# 2  [кодекс, кодекс, кодекс]
# 3                  [кодекс]
# 4        [конфликт интерес]
#
#                             Корпоративное управление  \
# 0  [собрание акционер, совет директор, компетенци...
# 1  [практика, акционер, акционер, акционер, акцио...
# 2  [хороший, российский практика, акционер, акцио...
# 3  [хороший, российский практика, собрание акцион...
# 4  [хороший, практика, акционер, ответственность,...
#
#                                  Устойчивое развитие
# 0  [соответствие, деятельность, деятельность, дея...
# 1                                   [дополнительный]
# 2                                     [деятельность]
# 3                   [управление устойчивый развитие]
# 4  [соответствие, стратегия, стратегия, риск, стр...
#
# [5 rows x 45 columns]

# %%
p = pd.DataFrame(true_expert_found_words).rename(columns={0: "topic", 1: "words"})
p.head()
# Out:
#                       topic                                              words
# 0  Корпоративное управление  [собрание акционер, совет директор, компетенци...
# 1  Корпоративное управление  [практика, акционер, акционер, акционер, акцио...
# 2  Корпоративное управление  [хороший, российский практика, акционер, акцио...
# 3  Корпоративное управление  [хороший, российский практика, собрание акцион...
# 4  Корпоративное управление  [хороший, практика, акционер, ответственность,...

# %%
print(f"{'Topic':<35} {'Average Word Length':<20} Count")
for topic, val in p.groupby("topic")["words"].apply(list).items():
    print(f"{topic:<35} {sum([len(e) for e in val]) / len(val):05.2f} {len(val)}")
# Out:
# Topic                               Average Word Length  Count
# Биоразнообразие                     08.58 26
# Вода                                13.52 27
# Воздух                              07.85 20
# Климат                              10.52 25
# Корпоративное управление            07.00 9
# Лидерство                           05.00 1
# Отношения с инвесторами             08.18 11
# Отчетность и прозрачность           07.30 10
# Потребители. Доступность            06.85 13
# Потребители. Ценовая политика       07.50 14
# Права человека                      11.29 24
# Риски                               10.00 22
# Сотрудники. Наем и увольнение       06.00 2
# Экологичность продукта              06.71 7
# Экология в целом                    08.72 18
# Энергия                             10.88 26
# Этика и антикоррупция               06.65 17

# %%
def init_matrix(topics: pd.DataFrame) -> np.ndarray:
    matrix = np.zeros(topics_vectors.shape)
    # topic	weight	type	word
    for idx, row in topics.iterrows():
        matrix[label2idx[row["topic"]], word2idx[row["word"]]] = 1
    return matrix


def fit(matrix, vectors, labels):
    for vector, label in zip(vectors, labels):
        for i in range(matrix.shape[0]):
            if not label2idx.get(label, False):
                continue
            #print(label)
            if i == label2idx[label]:
                matrix[i] += vector
            else:
                matrix[i] -= vector
    return matrix


def test(matrix, vectors, labels, debug=False):
    total = 0
    pred_labels = []
    for vector, label in zip(vectors, labels):
        res = np.argmax(vector @ matrix.T)
        # print(np.argmax(vector @ matrix.T))
        total += label == idx2label[res]
        pred_labels.append(idx2label[res])
        if debug and label != idx2label[res]:
            print("expected", label, "result", idx2label[res], vector @ matrix.T)
    return pred_labels, total / len(labels)

# %%
matrix = init_matrix(topics)
for i in tqdm(range(2)):
    matrix = fit(matrix, vector, labels)
    pred_labels, acc = test(matrix, vector, labels, False)
    print(acc)

pred_labels, acc = test(matrix, vector, labels, False)
acc
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 26.18it/s]
# 0.7904411764705882
# 0.7867647058823529
# 0.7867647058823529

# %%
matrix_df = pd.DataFrame(matrix, columns=topics["word"].tolist(), index=topics["topic"].unique().tolist())
matrix_df
# Out:
#                                  воздействие  окружающая среда  природа  \
# Экология в целом                       -76.0               0.0    -16.0
# Климат                                 -76.0               0.0    -16.0
# Энергия                                -76.0               0.0    -16.0
# Воздух                                 -35.0               0.0     13.0
# Вода                                   -51.0               0.0    -16.0
# Отходы и циклическая экономика         -59.0               0.0    -16.0
# Биоразнообразие                        -76.0               0.0    -16.0
# Рекультивация земель                   -76.0               0.0    -16.0
# Экологичность продукта                 -71.0               0.0    -16.0
# !Персонал в целом                      -76.0               0.0    -16.0
# Обучение и развитие                    -76.0               0.0    -16.0
# Сотрудники. Вовлеченность и мот        -76.0               0.0    -16.0
# Оплата труда                           -76.0               0.0    -16.0
# Сотрудники. Здоровье и благопол        -76.0               0.0    -16.0
# Сотрудники. Наем и увольнение          -76.0               0.0    -16.0
# Сотрудники. Корпоративная культ        -76.0               0.0    -16.0
# Сотрудники. Безопасность и охра        -75.0               0.0    -16.0
# Сотрудники. Профсоюз и Коллекти        -76.0               0.0    -16.0
# Потребители. Доступность               -76.0               0.0    -16.0
# Потребители. Сервис и коммуника        -76.0               0.0    -16.0
# Потребители. Персональные данны        -76.0               0.0    -16.0
# Потребители. Здоровье и благопо        -76.0               0.0    -16.0
# Потребители. Маркетинг, продажи        -76.0               0.0    -16.0
# Потребители. Удовлетворенность         -76.0               0.0    -16.0
# Потребители. Качество и безопас        -76.0               0.0    -16.0
# Потребители. Ценовая политика          -76.0               0.0    -16.0
# Поставщики в целом                     -76.0               0.0    -16.0
# Малый и локальный бизнес               -76.0               0.0    -16.0
# Поставщики. Работники                  -76.0               0.0    -16.0
# Поставщики. Экология                   -64.0               0.0    -16.0
# Закупки и антикоррупция                -75.0               0.0    -16.0
# Заинтересованные стороны               -60.0               0.0    -16.0
# Коренные народы и местные сообщ        -76.0               0.0    -16.0
# Сотрудники. Волонтерство               -76.0               0.0    -16.0
# Социальные инвестиции и благотв        -76.0               0.0    -16.0
# Отчетность и прозрачность              -76.0               0.0    -16.0
# Отношения с инвесторами                -76.0               0.0    -16.0
# !Инновации                             -76.0               0.0    -16.0
# !Кибербезопасность                     -76.0               0.0    -16.0
# Права человека                         -76.0               1.0    -16.0
# Лидерство                              -76.0               0.0    -16.0
# Риски                                  -75.0               0.0    -16.0
# Этика и антикоррупция                  -35.0               1.0    -15.0
# Корпоративное управление               -76.0               0.0    -16.0
# Устойчивое развитие                    -76.0               0.0    -12.0
#
#                                  природоохранный  экологический  экологичный  \
# Экология в целом                           -20.0          -66.0         -8.0
# Климат                                     -20.0          -66.0         -8.0
# Энергия                                    -20.0          -66.0         -8.0
# Воздух                                     -15.0          -53.0         -8.0
# Вода                                       -16.0          -62.0         -4.0
# Отходы и циклическая экономика             -12.0          -49.0         -8.0
# Биоразнообразие                            -20.0          -66.0         -8.0
# Рекультивация земель                       -20.0          -66.0         -8.0
# Экологичность продукта                     -20.0          -54.0         -4.0
# !Персонал в целом                          -20.0          -65.0         -8.0
# Обучение и развитие                        -20.0          -66.0         -8.0
# Сотрудники. Вовлеченность и мот            -20.0          -66.0         -8.0
# Оплата труда                               -20.0          -66.0         -8.0
# Сотрудники. Здоровье и благопол            -20.0          -66.0         -8.0
# Сотрудники. Наем и увольнение              -20.0          -66.0         -8.0
# Сотрудники. Корпоративная культ            -20.0          -66.0         -8.0
# Сотрудники. Безопасность и охра            -20.0          -65.0         -7.0
# Сотрудники. Профсоюз и Коллекти            -20.0          -62.0         -8.0
# Потребители. Доступность                   -20.0          -65.0         -8.0
# Потребители. Сервис и коммуника            -20.0          -66.0         -8.0
# Потребители. Персональные данны            -20.0          -65.0         -7.0
# Потребители. Здоровье и благопо            -20.0          -66.0         -8.0
# Потребители. Маркетинг, продажи            -20.0          -66.0         -7.0
# Потребители. Удовлетворенность             -20.0          -65.0         -7.0
# Потребители. Качество и безопас            -20.0          -66.0         -8.0
# Потребители. Ценовая политика              -20.0          -66.0         -8.0
# Поставщики в целом                         -20.0          -66.0         -8.0
# Малый и локальный бизнес                   -20.0          -66.0         -8.0
# Поставщики. Работники                      -20.0          -66.0         -8.0
# Поставщики. Экология                       -20.0          -66.0         -8.0
# Закупки и антикоррупция                    -20.0          -65.0         -8.0
# Заинтересованные стороны                   -20.0          -58.0         -8.0
# Коренные народы и местные сообщ            -20.0          -66.0         -8.0
# Сотрудники. Волонтерство                   -20.0          -66.0         -8.0
# Социальные инвестиции и благотв            -20.0          -65.0         -8.0
# Отчетность и прозрачность                  -20.0          -66.0         -8.0
# Отношения с инвесторами                    -20.0          -66.0         -8.0
# !Инновации                                 -20.0          -66.0         -8.0
# !Кибербезопасность                         -20.0          -66.0         -8.0
# Права человека                             -20.0          -65.0         -8.0
# Лидерство                                  -20.0          -66.0         -8.0
# Риски                                      -20.0          -54.0         -3.0
# Этика и антикоррупция                        5.0           -1.0         -7.0
# Корпоративное управление                   -20.0          -66.0         -4.0
# Устойчивое развитие                        -20.0          -66.0         -8.0
#
#                                  влияние  документ  документация  защита  ...  \
# Экология в целом                   -46.0     -52.0         -12.0   -32.0  ...
# Климат                             -46.0     -52.0         -12.0   -32.0  ...
# Энергия                            -46.0     -52.0         -12.0   -32.0  ...
# Воздух                             -30.0     -52.0         -12.0   -28.0  ...
# Вода                               -34.0     -48.0           0.0   -32.0  ...
# Отходы и циклическая экономика     -38.0     -52.0         -12.0   -32.0  ...
# Биоразнообразие                    -46.0     -52.0         -12.0   -32.0  ...
# Рекультивация земель               -46.0     -52.0         -12.0   -32.0  ...
# Экологичность продукта             -46.0     -48.0         -12.0   -32.0  ...
# !Персонал в целом                  -46.0     -52.0         -12.0   -32.0  ...
# Обучение и развитие                -46.0     -44.0         -12.0   -20.0  ...
# Сотрудники. Вовлеченность и мот    -46.0     -52.0         -12.0   -32.0  ...
# Оплата труда                       -46.0     -52.0         -12.0   -32.0  ...
# Сотрудники. Здоровье и благопол    -46.0     -52.0         -12.0   -32.0  ...
# Сотрудники. Наем и увольнение      -46.0     -52.0         -12.0   -32.0  ...
# Сотрудники. Корпоративная культ    -42.0     -52.0         -12.0   -32.0  ...
# Сотрудники. Безопасность и охра    -46.0     -52.0         -12.0   -31.0  ...
# Сотрудники. Профсоюз и Коллекти    -42.0     -44.0         -12.0   -28.0  ...
# Потребители. Доступность           -46.0     -52.0         -12.0   -32.0  ...
# Потребители. Сервис и коммуника    -46.0     -52.0         -12.0   -32.0  ...
# Потребители. Персональные данны    -46.0     -52.0         -12.0   -32.0  ...
# Потребители. Здоровье и благопо    -46.0     -48.0         -12.0   -32.0  ...
# Потребители. Маркетинг, продажи    -46.0     -52.0         -12.0   -32.0  ...
# Потребители. Удовлетворенность     -46.0     -52.0         -12.0   -32.0  ...
# Потребители. Качество и безопас    -46.0     -52.0         -12.0   -32.0  ...
# Потребители. Ценовая политика      -46.0     -52.0         -12.0   -31.0  ...
# Поставщики в целом                 -46.0     -52.0         -12.0   -32.0  ...
# Малый и локальный бизнес           -46.0     -52.0         -12.0   -32.0  ...
# Поставщики. Работники              -42.0     -52.0         -12.0   -32.0  ...
# Поставщики. Экология               -38.0     -36.0         -12.0    -4.0  ...
# Закупки и антикоррупция            -46.0     -52.0         -12.0   -32.0  ...
# Заинтересованные стороны           -21.0     -40.0          -8.0   -27.0  ...
# Коренные народы и местные сообщ    -46.0     -52.0         -12.0   -32.0  ...
# Сотрудники. Волонтерство           -46.0     -52.0         -12.0   -32.0  ...
# Социальные инвестиции и благотв    -46.0     -52.0         -12.0   -32.0  ...
# Отчетность и прозрачность          -46.0     -52.0         -12.0   -32.0  ...
# Отношения с инвесторами            -46.0     -52.0         -12.0   -32.0  ...
# !Инновации                         -46.0     -52.0         -12.0   -32.0  ...
# !Кибербезопасность                 -46.0     -52.0         -12.0   -31.0  ...
# Права человека                     -46.0     -52.0         -12.0   -31.0  ...
# Лидерство                          -46.0     -52.0         -12.0   -32.0  ...
# Риски                              -46.0     -52.0         -12.0   -28.0  ...
# Этика и антикоррупция              -33.0     -27.0          -3.0   -27.0  ...
# Корпоративное управление           -46.0     -48.0         -12.0   -32.0  ...
# Устойчивое развитие                -46.0     -32.0         -12.0   -28.0  ...
#
#                                  соответствовать   управлять  фокусный  \
# Экология в целом                              0.0       -2.0       0.0
# Климат                                        0.0       -2.0       0.0
# Энергия                                       0.0       -2.0       0.0
# Воздух                                        0.0       -2.0       0.0
# Вода                                          0.0       -2.0       0.0
# Отходы и циклическая экономика                0.0       -2.0       0.0
# Биоразнообразие                               0.0       -2.0       0.0
# Рекультивация земель                          0.0       -2.0       0.0
# Экологичность продукта                        0.0       -2.0       0.0
# !Персонал в целом                             0.0       -2.0       0.0
# Обучение и развитие                           0.0       -2.0       0.0
# Сотрудники. Вовлеченность и мот               0.0       -1.0       0.0
# Оплата труда                                  0.0       -2.0       0.0
# Сотрудники. Здоровье и благопол               0.0       -2.0       0.0
# Сотрудники. Наем и увольнение                 0.0       -2.0       0.0
# Сотрудники. Корпоративная культ               0.0       -2.0       0.0
# Сотрудники. Безопасность и охра               0.0       -2.0       0.0
# Сотрудники. Профсоюз и Коллекти               0.0       -1.0       0.0
# Потребители. Доступность                      0.0       -2.0       0.0
# Потребители. Сервис и коммуника               0.0       -2.0       0.0
# Потребители. Персональные данны               0.0       -2.0       0.0
# Потребители. Здоровье и благопо               0.0       -2.0       0.0
# Потребители. Маркетинг, продажи               0.0       -2.0       0.0
# Потребители. Удовлетворенность                0.0       -2.0       0.0
# Потребители. Качество и безопас               0.0       -2.0       0.0
# Потребители. Ценовая политика                 0.0       -2.0       0.0
# Поставщики в целом                            0.0       -2.0       0.0
# Малый и локальный бизнес                      0.0       -2.0       0.0
# Поставщики. Работники                         0.0       -2.0       0.0
# Поставщики. Экология                          0.0       -2.0       0.0
# Закупки и антикоррупция                       0.0       -2.0       0.0
# Заинтересованные стороны                      0.0       -2.0       0.0
# Коренные народы и местные сообщ               0.0       -2.0       0.0
# Сотрудники. Волонтерство                      0.0       -2.0       0.0
# Социальные инвестиции и благотв               0.0       -2.0       0.0
# Отчетность и прозрачность                     0.0       -2.0       0.0
# Отношения с инвесторами                       0.0       -2.0       0.0
# !Инновации                                    0.0       -2.0       0.0
# !Кибербезопасность                            0.0       -2.0       0.0
# Права человека                                0.0       -1.0       0.0
# Лидерство                                     1.0       -1.0       1.0
# Риски                                         0.0       -2.0       0.0
# Этика и антикоррупция                         0.0        2.0       0.0
# Корпоративное управление                      0.0       -2.0       0.0
# Устойчивое развитие                           0.0       -2.0       0.0
#
#                                  формировать  iso 14001  \
# Экология в целом                       -10.0       -4.0
# Климат                                 -10.0       -4.0
# Энергия                                -10.0       -4.0
# Воздух                                 -10.0       -4.0
# Вода                                   -10.0       -4.0
# Отходы и циклическая экономика         -10.0       -4.0
# Биоразнообразие                        -10.0       -4.0
# Рекультивация земель                   -10.0       -4.0
# Экологичность продукта                 -10.0       -4.0
# !Персонал в целом                      -10.0       -4.0
# Обучение и развитие                    -10.0       -4.0
# Сотрудники. Вовлеченность и мот        -10.0       -4.0
# Оплата труда                           -10.0       -4.0
# Сотрудники. Здоровье и благопол        -10.0       -4.0
# Сотрудники. Наем и увольнение          -10.0       -4.0
# Сотрудники. Корпоративная культ        -10.0       -4.0
# Сотрудники. Безопасность и охра        -10.0       -4.0
# Сотрудники. Профсоюз и Коллекти        -10.0       -4.0
# Потребители. Доступность               -10.0       -4.0
# Потребители. Сервис и коммуника        -10.0       -4.0
# Потребители. Персональные данны        -10.0       -4.0
# Потребители. Здоровье и благопо        -10.0       -4.0
# Потребители. Маркетинг, продажи        -10.0       -4.0
# Потребители. Удовлетворенность         -10.0       -4.0
# Потребители. Качество и безопас        -10.0       -4.0
# Потребители. Ценовая политика          -10.0       -4.0
# Поставщики в целом                     -10.0       -4.0
# Малый и локальный бизнес               -10.0       -4.0
# Поставщики. Работники                   -6.0       -4.0
# Поставщики. Экология                    -6.0       -4.0
# Закупки и антикоррупция                -10.0       -4.0
# Заинтересованные стороны                -2.0       -4.0
# Коренные народы и местные сообщ        -10.0       -4.0
# Сотрудники. Волонтерство               -10.0       -4.0
# Социальные инвестиции и благотв        -10.0       -4.0
# Отчетность и прозрачность              -10.0       -4.0
# Отношения с инвесторами                -10.0       -4.0
# !Инновации                             -10.0       -4.0
# !Кибербезопасность                     -10.0       -4.0
# Права человека                         -10.0       -4.0
# Лидерство                               -9.0       -3.0
# Риски                                  -10.0       -4.0
# Этика и антикоррупция                   -6.0        4.0
# Корпоративное управление               -10.0       -4.0
# Устойчивое развитие                    -10.0       -4.0
#
#                                  science based targets initiative sbti  \
# Экология в целом                                                   0.0
# Климат                                                             0.0
# Энергия                                                            0.0
# Воздух                                                             0.0
# Вода                                                               0.0
# Отходы и циклическая экономика                                     0.0
# Биоразнообразие                                                    0.0
# Рекультивация земель                                               0.0
# Экологичность продукта                                             0.0
# !Персонал в целом                                                  0.0
# Обучение и развитие                                                0.0
# Сотрудники. Вовлеченность и мот                                    0.0
# Оплата труда                                                       0.0
# Сотрудники. Здоровье и благопол                                    0.0
# Сотрудники. Наем и увольнение                                      0.0
# Сотрудники. Корпоративная культ                                    0.0
# Сотрудники. Безопасность и охра                                    0.0
# Сотрудники. Профсоюз и Коллекти                                    0.0
# Потребители. Доступность                                           0.0
# Потребители. Сервис и коммуника                                    0.0
# Потребители. Персональные данны                                    0.0
# Потребители. Здоровье и благопо                                    0.0
# Потребители. Маркетинг, продажи                                    0.0
# Потребители. Удовлетворенность                                     0.0
# Потребители. Качество и безопас                                    0.0
# Потребители. Ценовая политика                                      0.0
# Поставщики в целом                                                 0.0
# Малый и локальный бизнес                                           0.0
# Поставщики. Работники                                              0.0
# Поставщики. Экология                                               0.0
# Закупки и антикоррупция                                            0.0
# Заинтересованные стороны                                           0.0
# Коренные народы и местные сообщ                                    0.0
# Сотрудники. Волонтерство                                           0.0
# Социальные инвестиции и благотв                                    0.0
# Отчетность и прозрачность                                          0.0
# Отношения с инвесторами                                            0.0
# !Инновации                                                         0.0
# !Кибербезопасность                                                 0.0
# Права человека                                                     0.0
# Лидерство                                                          1.0
# Риски                                                              0.0
# Этика и антикоррупция                                              0.0
# Корпоративное управление                                           0.0
# Устойчивое развитие                                                0.0
#
#                                  верификация  целевый показатель  \
# Экология в целом                        -6.0                 0.0
# Климат                                  -6.0                 0.0
# Энергия                                 -6.0                 0.0
# Воздух                                  -6.0                 0.0
# Вода                                    -6.0                 0.0
# Отходы и циклическая экономика          -6.0                 0.0
# Биоразнообразие                         -6.0                 0.0
# Рекультивация земель                    -6.0                 0.0
# Экологичность продукта                  -2.0                 0.0
# !Персонал в целом                       -6.0                 0.0
# Обучение и развитие                     -6.0                 0.0
# Сотрудники. Вовлеченность и мот         -6.0                 0.0
# Оплата труда                            -6.0                 0.0
# Сотрудники. Здоровье и благопол         -6.0                 0.0
# Сотрудники. Наем и увольнение           -6.0                 0.0
# Сотрудники. Корпоративная культ         -6.0                 0.0
# Сотрудники. Безопасность и охра         -6.0                 0.0
# Сотрудники. Профсоюз и Коллекти         -6.0                 0.0
# Потребители. Доступность                -6.0                 0.0
# Потребители. Сервис и коммуника         -6.0                 0.0
# Потребители. Персональные данны         -6.0                 0.0
# Потребители. Здоровье и благопо         -6.0                 0.0
# Потребители. Маркетинг, продажи         -6.0                 0.0
# Потребители. Удовлетворенность          -6.0                 0.0
# Потребители. Качество и безопас         -6.0                 0.0
# Потребители. Ценовая политика           -6.0                 0.0
# Поставщики в целом                      -6.0                 0.0
# Малый и локальный бизнес                -6.0                 0.0
# Поставщики. Работники                   -6.0                 0.0
# Поставщики. Экология                    -6.0                 0.0
# Закупки и антикоррупция                 -6.0                 0.0
# Заинтересованные стороны                -5.0                 0.0
# Коренные народы и местные сообщ         -6.0                 0.0
# Сотрудники. Волонтерство                -6.0                 0.0
# Социальные инвестиции и благотв         -6.0                 0.0
# Отчетность и прозрачность               -6.0                 0.0
# Отношения с инвесторами                 -6.0                 0.0
# !Инновации                              -6.0                 0.0
# !Кибербезопасность                      -6.0                 0.0
# Права человека                          -6.0                 0.0
# Лидерство                               -5.0                 1.0
# Риски                                    2.0                 0.0
# Этика и антикоррупция                   -6.0                 0.0
# Корпоративное управление                -6.0                 0.0
# Устойчивое развитие                     -6.0                 0.0
#
#                                  система экологического менеджмент  сэм
# Экология в целом                                               0.0 -8.0
# Климат                                                         0.0 -8.0
# Энергия                                                        0.0 -8.0
# Воздух                                                         0.0 -8.0
# Вода                                                           0.0 -8.0
# Отходы и циклическая экономика                                 0.0 -8.0
# Биоразнообразие                                                0.0 -8.0
# Рекультивация земель                                           0.0 -8.0
# Экологичность продукта                                         0.0 -8.0
# !Персонал в целом                                              0.0 -8.0
# Обучение и развитие                                            0.0 -8.0
# Сотрудники. Вовлеченность и мот                                0.0 -8.0
# Оплата труда                                                   0.0 -8.0
# Сотрудники. Здоровье и благопол                                0.0 -8.0
# Сотрудники. Наем и увольнение                                  0.0 -8.0
# Сотрудники. Корпоративная культ                                0.0 -8.0
# Сотрудники. Безопасность и охра                                0.0 -8.0
# Сотрудники. Профсоюз и Коллекти                                0.0 -8.0
# Потребители. Доступность                                       0.0 -8.0
# Потребители. Сервис и коммуника                                0.0 -8.0
# Потребители. Персональные данны                                0.0 -8.0
# Потребители. Здоровье и благопо                                0.0 -8.0
# Потребители. Маркетинг, продажи                                0.0 -8.0
# Потребители. Удовлетворенность                                 0.0 -8.0
# Потребители. Качество и безопас                                0.0 -8.0
# Потребители. Ценовая политика                                  0.0 -8.0
# Поставщики в целом                                             0.0 -8.0
# Малый и локальный бизнес                                       0.0 -8.0
# Поставщики. Работники                                          0.0 -8.0
# Поставщики. Экология                                           0.0 -8.0
# Закупки и антикоррупция                                        0.0 -8.0
# Заинтересованные стороны                                       0.0 -8.0
# Коренные народы и местные сообщ                                0.0 -8.0
# Сотрудники. Волонтерство                                       0.0 -8.0
# Социальные инвестиции и благотв                                0.0 -8.0
# Отчетность и прозрачность                                      0.0 -8.0
# Отношения с инвесторами                                        0.0 -8.0
# !Инновации                                                     0.0 -8.0
# !Кибербезопасность                                             0.0 -8.0
# Права человека                                                 0.0 -8.0
# Лидерство                                                      1.0 -7.0
# Риски                                                          0.0 -8.0
# Этика и антикоррупция                                          0.0  8.0
# Корпоративное управление                                       0.0 -8.0
# Устойчивое развитие                                            0.0 -8.0
#
# [45 rows x 3650 columns]

# %%
np.save("etalon/et_expert.npy", matrix)
matrix_df.to_csv("etalon/et_expert_matrix.csv")
matrix_df.T.to_csv("etalon/et_expert_matrix.T.csv")

# %%
results = []
for col in tqdm(matrix_df.columns):
    max_val = matrix_df[col].max()[0] if type(matrix_df[col].max()) is not float else matrix_df[col].max()
    min_val = matrix_df[col].min()[0] if type(matrix_df[col].min()) is not float else matrix_df[col].min()
    if max_val > 0:
        results.append((col, max_val))
    if min_val < -2000:
        results.append((col, min_val))

results_df = pd.DataFrame(results, columns=["word", "val"])
results_df.to_csv("etalon/et_matrix_words.csv")
# Out:
# 100%|██████████████████████████████████████| 3650/3650 [00:06<00:00, 570.53it/s]

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

print(
    "accuracy",
    accuracy_score(
        labels,
        pred_labels,
    ),
)
print(
    "f1",
    f1_score(
        labels,
        pred_labels,
        average="macro",
    ),
)
print(
    "precision",
    precision_score(
        labels,
        pred_labels,
        average="macro",
    ),
)
print(
    "recall",
    recall_score(
        labels,
        pred_labels,
        average="macro",
    ),
)
# Out:
# accuracy 0.7867647058823529
# f1 0.6545817743978198
# precision 0.7123900837985843
# recall 0.6502576745310309
# /Users/darlinkennedy/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Topic assignment

# %%
from typing import Optional
from typing import Union
import typer

# %%
df = pd.read_csv("paragraphs/paragraphs_2022.csv")  # , usecols=["cleaned_text"], nrows=ROWS
df = df.dropna().reset_index(drop=True)
df.shape
# Out:
# (14154, 8)

# %%
text = df.loc[100, "cleaned_text"]
# text = "Доля сотрудников, охваченных коллективными договорами".lower()


def test_algos(text: str, verbouse: bool = False) -> dict[str, Union[str, float, list[str],None]]:
    arr = []
    result = {"text": text}
    vector = np.zeros(matrix.shape[1])

    for key, regex in re_dict.items():
        words = regex.findall(text)
        paragraph_dict = copy.deepcopy(base_dict)
        #print(paragraph_dict)
        importance = 0
        paragraph_len = len(text.split())
        base_words = 0
        for word in words:
            if type(word) is tuple:
                print(word)
                word = word[0]
            paragraph_dict[key][word] = sheets_dict[key][word]
            importance += sheets_dict[key][word] > 1
            vector[word2idx[word]] = 1
            base_words += 1
        # if base_words / paragraph_len < 0.1 or importance < 1:
        #     arr.append((key, 0, 0, []))
        #     continue

        dist = cosine_similarity(X=[list(sheets_dict[key].values())], Y=[list(paragraph_dict[key].values())])[0][0]
        arr.append((copy.deepcopy(key), copy.deepcopy(dist), copy.deepcopy(importance), copy.deepcopy(words)))
        result = {**result, **{f"{key}_dist": dist, f"{key}_importance": importance, f"{key}_words": words}}
    if verbouse:
        print("\nexpert")
    res = vector @ matrix.T
    for idx in np.argsort(res)[::-1]:
        if verbouse:
            print(idx2label[idx], res[idx])
        result[f"{idx2label[idx]}_expert"] = res[idx]

    if verbouse:
        print("\ncos")
        for key, dist, importance, words in sorted(arr, key=lambda x: x[1], reverse=True):
            print(f"{key} расстояние {dist:.4f} важные слова {importance} {copy.deepcopy(set(words))}")
    return result

# %%
text = df.loc[100, "cleaned_text"]
print(text)
test_algos(text, True)
a = 0
# Out:
# наш нераспределённый стоимость 2022 год составить 18,2 млрд руб. увеличиться 152,2 сравнение предыдущий год данный изменение обусловить положительный динамика показатель ebitda число завершение продажа силовой остров снижение ряд расход совместно решение выплачивать дивиденд 2022 год привести рост нераспределённый прибыль
# ('показатель', '')
# ('снижение', '')
# ('рост', '')
#
# expert
# Климат -723.0
# Вода -727.0
# Воздух -760.0
# Энергия -777.0
# Экология в целом -952.0
# Риски -984.0
# Потребители. Ценовая политика -1000.0
# Биоразнообразие -1072.0
# Отношения с инвесторами -1077.0
# Корпоративное управление -1080.0
# Отчетность и прозрачность -1100.0
# Права человека -1100.0
# Экологичность продукта -1112.0
# Потребители. Сервис и коммуника -1119.0
# Сотрудники. Наем и увольнение -1120.0
# Потребители. Доступность -1121.0
# Отходы и циклическая экономика -1128.0
# Потребители. Удовлетворенность -1130.0
# Потребители. Качество и безопас -1131.0
# Рекультивация земель -1132.0
# Коренные народы и местные сообщ -1133.0
# Социальные инвестиции и благотв -1134.0
# Закупки и антикоррупция -1134.0
# Заинтересованные стороны -1136.0
# !Кибербезопасность -1136.0
# Лидерство -1136.0
# Малый и локальный бизнес -1136.0
# !Персонал в целом -1136.0
# Обучение и развитие -1136.0
# Этика и антикоррупция -1136.0
# Потребители. Здоровье и благопо -1136.0
# Оплата труда -1136.0
# Поставщики в целом -1136.0
# Поставщики. Работники -1136.0
# Поставщики. Экология -1136.0
# Потребители. Маркетинг, продажи -1136.0
# Потребители. Персональные данны -1136.0
# Сотрудники. Безопасность и охра -1136.0
# Сотрудники. Вовлеченность и мот -1136.0
# Сотрудники. Волонтерство -1136.0
# Сотрудники. Здоровье и благопол -1136.0
# Сотрудники. Корпоративная культ -1136.0
# Сотрудники. Профсоюз и Коллекти -1136.0
# Устойчивое развитие -1136.0
# !Инновации -1136.0
#
# cos
# Отношения с инвесторами расстояние 0.4220 важные слова 1 {'прибыль', 'дивиденд'}
# Вода расстояние 0.2068 важные слова 1 {'снижение', 'расход'}
# Потребители. Сервис и коммуника расстояние 0.2016 важные слова 0 {'показатель', 'предыдущий', 'рост', 'снижение', 'решение'}
# Энергия расстояние 0.1129 важные слова 0 {'показатель', 'снижение', 'расход', 'решение', 'динамика'}
# Потребители. Ценовая политика расстояние 0.1000 важные слова 0 {'снижение', 'рост', 'прибыль'}
# Потребители. Доступность расстояние 0.0990 важные слова 0 {'решение'}
# Климат расстояние 0.0860 важные слова 0 {('показатель', ''), ('рост', ''), ('снижение', '')}
# Коренные народы и местные сообщ расстояние 0.0676 важные слова 0 {'расход'}
# Потребители. Удовлетворенность расстояние 0.0601 важные слова 0 {'динамика', 'положительный'}
# Рекультивация земель расстояние 0.0587 важные слова 0 {'рост'}
# Социальные инвестиции и благотв расстояние 0.0524 важные слова 0 {'положительный'}
# Отходы и циклическая экономика расстояние 0.0487 важные слова 0 {'снижение', 'стоимость'}
# Закупки и антикоррупция расстояние 0.0420 важные слова 0 {'стоимость'}
# Потребители. Качество и безопас расстояние 0.0416 важные слова 0 {'динамика', 'продажа'}
# Риски расстояние 0.0365 важные слова 0 {'динамика'}
# Экология в целом расстояние 0.0000 важные слова 0 set()
# Воздух расстояние 0.0000 важные слова 0 set()
# Биоразнообразие расстояние 0.0000 важные слова 0 set()
# Экологичность продукта расстояние 0.0000 важные слова 0 set()
# !Персонал в целом расстояние 0.0000 важные слова 0 set()
# Обучение и развитие расстояние 0.0000 важные слова 0 set()
# Сотрудники. Вовлеченность и мот расстояние 0.0000 важные слова 0 set()
# Оплата труда расстояние 0.0000 важные слова 0 set()
# Сотрудники. Здоровье и благопол расстояние 0.0000 важные слова 0 set()
# Сотрудники. Наем и увольнение расстояние 0.0000 важные слова 0 set()
# Сотрудники. Корпоративная культ расстояние 0.0000 важные слова 0 set()
# Сотрудники. Безопасность и охра расстояние 0.0000 важные слова 0 set()
# Сотрудники. Профсоюз и Коллекти расстояние 0.0000 важные слова 0 set()
# Потребители. Персональные данны расстояние 0.0000 важные слова 0 set()
# Потребители. Здоровье и благопо расстояние 0.0000 важные слова 0 set()
# Потребители. Маркетинг, продажи расстояние 0.0000 важные слова 0 set()
# Поставщики в целом расстояние 0.0000 важные слова 0 set()
# Малый и локальный бизнес расстояние 0.0000 важные слова 0 set()
# Поставщики. Работники расстояние 0.0000 важные слова 0 set()
# Поставщики. Экология расстояние 0.0000 важные слова 0 set()
# Заинтересованные стороны расстояние 0.0000 важные слова 0 set()
# Сотрудники. Волонтерство расстояние 0.0000 важные слова 0 set()
# Отчетность и прозрачность расстояние 0.0000 важные слова 0 set()
# !Инновации расстояние 0.0000 важные слова 0 set()
# !Кибербезопасность расстояние 0.0000 важные слова 0 set()
# Права человека расстояние 0.0000 важные слова 0 set()
# Лидерство расстояние 0.0000 важные слова 0 set()
# Этика и антикоррупция расстояние 0.0000 важные слова 0 set()
# Корпоративное управление расстояние 0.0000 важные слова 0 set()
# Устойчивое развитие расстояние 0.0000 важные слова 0 set()

# %%
def get_scores(text: str) -> dict[str, Union[str, float, list[str],None]]:
    paragraph_dict = copy.deepcopy(base_dict)
    paragraph_importance = copy.deepcopy(importance_dict)
    found_words = False
    base_words = {}
    advanced_words = {}
    vector_exp = np.zeros(matrix.shape[1])
    if type(text) is float:
        print(text, type(text))
        return {}
    paragraph_len = len(text.split())

    total_found = 0
    for key, regex in re_dict.items():
        words = regex.findall(text)
        # advanced_words_found = re_advanced_dict[key].findall(text)
        for word in words:
            found_words = True
            if type(word) is tuple:
                word = word[0]
            weight = sheets_dict[key][word]
            paragraph_dict[key][word] = weight
            paragraph_importance[key] += weight > 1

            vector_exp[word2idx[word]] = 1

        base_words[key] = len(words)
        total_found += len(words)
        # advanced_words[key] = len(advanced_words_found)

    debug_dict = {}
    if not found_words:
        res = {key: 0 for key in sheets_dict}
        debug_dict["total_found_words"] = total_found
        return {**res, **{"max_score_cos": None, "max_topic_cos": None, "count_words": None}, **debug_dict}

    topic_found = False
    res = {}
    for key, vector in sheets_dict.items():
        debug_dict[f"{key}_percent_of_words"] = base_words[key] / paragraph_len
        debug_dict[f"{key}_importance"] = paragraph_importance[key]
        debug_dict[f"{key}_base_words_count"] = base_words[key]
        if base_words[key] / paragraph_len < 0.1 or paragraph_importance[key] < 1:
            res[key] = 0
            continue
        sim = cosine_similarity(X=[list(vector.values())], Y=[list(paragraph_dict[key].values())])[0][0]
        res[key] = sim
        topic_found = True

    if not topic_found:
        res = {key: 0 for key in sheets_dict}
        return {**res, **{"max_score_cos": -100, "max_topic_cos": "безтемы", "count_words": None}, **debug_dict}

    paragraph_matrix = vector_exp @ matrix.T
    best_indicies = paragraph_matrix.argsort()[-2:][::-1]
    best_topics = [idx2label[i] for i in best_indicies]
    best_scores = paragraph_matrix[best_indicies]

    res_sorted = sorted(res.items(), key=lambda x: x[1], reverse=True)
    max_value = res_sorted[0]
    second_values = res_sorted[1]
    if second_values[1] == 0:
        second_values = (None, None)

    return {
        **res,
        **{
            "max_topic_cos": max_value[0],
            "max_score_cos": max_value[1],
            "second_max_topic_cos": second_values[0],
            "second_max_score_cos": second_values[1],
            "max_topic_exp": best_topics[0],
            "max_score_exp": best_scores[0],
            "second_max_topic_exp": best_topics[1],
            "second_max_score_exp": best_scores[1],
            "total_found_words": total_found,
        },
        **debug_dict,
    }

# %%
topics = []

i = 0
for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    text = row["cleaned_text"]
    res = get_scores(text)
    res["idx"] = idx
    if res.get("max_score_cos") is None:
        continue
    res["cleaned_text"] = text
    topics.append(res)
# Out:
# 100%|█████████████████████████████████████| 14154/14154 [08:48<00:00, 26.76it/s]

# %%
with open("topics.pkl", "wb") as fp:  # Pickling
    pickle.dump(topics, fp)

# %%
with open("topics.pkl", "rb") as f:
    topics = pickle.load(f)

# %%
topics = pd.DataFrame(topics).set_index(keys="idx")

# %%
topics.to_csv("paragraphs/all_topics_2022.csv")
topics.to_csv("paragraphs/all_topics_2022.csv.zip")

# %%
df = df.join(topics, rsuffix="topics")
df.head(10)
# Out:
#    Unnamed: 0  rsspp_index  index          company  paragraph  \
# 0           0         1428   1428  ЭЛ5-Энерго 2022         42
# 1           1         1428   1428  ЭЛ5-Энерго 2022         43
# 2           2         1428   1428  ЭЛ5-Энерго 2022         47
# 3           3         1428   1428  ЭЛ5-Энерго 2022         48
# 4           4         1428   1428  ЭЛ5-Энерго 2022         50
# 5           5         1428   1428  ЭЛ5-Энерго 2022         51
# 6           6         1428   1428  ЭЛ5-Энерго 2022         52
# 7           7         1428   1428  ЭЛ5-Энерго 2022         53
# 8           8         1428   1428  ЭЛ5-Энерго 2022         55
# 9           9         1428   1428  ЭЛ5-Энерго 2022         62
#
#                                        original_text  \
# 0  алибек айбекович тналин генеральный директор э...
# 1  в завершение хочу еще раз отметить, что данные...
# 2  представляем вашему вниманию наш второй отчет ...
# 3  наша гордость в 2022 году достижение показател...
# 4  мы прилагаем большие усилия для развития и мот...
# 5  мы осознаем свою ответственность и делаем все ...
# 6  2022 года мы можем с гордостью отметить достиж...
# 7  20232025 годов, их предыдущие версии неоднокра...
# 8  мы не только нарастили объем социальных инвест...
# 9  принципы подготовки отчетности отчет об устойч...
#
#                                         cleaned_text  year  Экология в целом  \
# 0  алибек айбекович тналин генеральный директор у...  2022               0.0
# 1  завершение хотеть отметить дать достижение явл...  2022               0.0
# 2  представлять ваш внимание наш второй отчёт уст...  2022               0.0
# 3  наш гордость 2022 год достижение показатель но...  2022               0.0
# 4  прилагать больший усилие развитие мотивация со...  2022               0.0
# 5  осознать ответственность делать возможный выпо...  2022               0.0
# 6  2022 год мочь гордость отметить достижение важ...  2022               0.0
# 7  20232025 год предыдущий версия неоднократно пр...  2022               0.0
# 8  нарастить объём социальный инвестиция сравнени...  2022               0.0
# 9  принцип подготовка отчётность отчёт устойчивый...  2022               0.0
#
#    Климат  ...  Устойчивое развитие_importance  \
# 0     0.0  ...                             0.0
# 1     0.0  ...                             2.0
# 2     0.0  ...                             1.0
# 3     0.0  ...                             0.0
# 4     0.0  ...                             0.0
# 5     0.0  ...                             0.0
# 6     0.0  ...                             0.0
# 7     0.0  ...                             0.0
# 8     0.0  ...                             1.0
# 9     0.0  ...                             2.0
#
#    Устойчивое развитие_base_words_count  \
# 0                                   0.0
# 1                                   2.0
# 2                                   3.0
# 3                                   0.0
# 4                                   1.0
# 5                                   0.0
# 6                                   1.0
# 7                                   0.0
# 8                                   2.0
# 9                                   6.0
#
#                                   cleaned_texttopics  second_max_topic_cos  \
# 0  алибек айбекович тналин генеральный директор у...                   NaN
# 1  завершение хотеть отметить дать достижение явл...                   NaN
# 2  представлять ваш внимание наш второй отчёт уст...                  None
# 3  наш гордость 2022 год достижение показатель но...                   NaN
# 4  прилагать больший усилие развитие мотивация со...                  None
# 5  осознать ответственность делать возможный выпо...             Лидерство
# 6  2022 год мочь гордость отметить достижение важ...                  None
# 7  20232025 год предыдущий версия неоднократно пр...                   NaN
# 8  нарастить объём социальный инвестиция сравнени...   Обучение и развитие
# 9  принцип подготовка отчётность отчёт устойчивый...   Обучение и развитие
#
#    second_max_score_cos              max_topic_exp  max_score_exp  \
# 0                   NaN                        NaN            NaN
# 1                   NaN                        NaN            NaN
# 2                   NaN  Отчетность и прозрачность         -862.0
# 3                   NaN                        NaN            NaN
# 4                   NaN             Права человека        -1674.0
# 5              0.233224           Экология в целом         -626.0
# 6                   NaN           Экология в целом        -1212.0
# 7                   NaN                        NaN            NaN
# 8              0.245327  Отчетность и прозрачность         -858.0
# 9              0.254588           Экология в целом        -2908.0
#
#    second_max_topic_exp  second_max_score_exp  total_found_words
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
# 2                 Риски                -902.0               26.0
# 3                   NaN                   NaN                NaN
# 4      Экология в целом               -1866.0               57.0
# 5        Права человека                -652.0               34.0
# 6                Климат               -1256.0               37.0
# 7                   NaN                   NaN                NaN
# 8                  Вода                -876.0               42.0
# 9                 Риски               -3183.0               92.0
#
# [10 rows x 199 columns]

# %%
df.to_csv("paragraphs/paragrapghs_with_topisc_2022.csv")
df.to_csv("paragraphs/paragrapghs_with_topisc_2022.csv.zip")
